# %%
import json
from lyricsgenius import Genius
from IPython.core.display import HTML
import requests
import pandas as pd


client_access_token= "Giscxt8OHKklvb-8yq2neCKQ6furo2aShx9hMC0fdrsNw4Hq85BOOlh6YpIG4zFd"

search_term = "Gorillaz"
genius_search_url = f"http://api.genius.com/search?q="+search_term+"m&access_token="+client_access_token
#print(genius_search_url)
response = requests.get(genius_search_url)
json_data = response.json()

#print(json_data['response']['hits'][0])

#Obtener títulos de canciones
for song in json_data['response']['hits']:
    print(song['result']['full_title'])
#Obtener mosaicos de canciones y recuentos de páginas  vistas
print("_________________________")
print(json_data['response']['hits'][0])
for song in json_data['response']['hits']:
   print(song['result']['full_title'], song['result']['stats']['pageviews'])
# Out:
# Feel Good Inc. by Gorillaz (Ft. De La Soul)
# Clint Eastwood by Gorillaz (Ft. Del The Funky Homosapien)
# Saturnz Barz by Gorillaz (Ft. Popcaan)
# On Melancholy Hill by Gorillaz
# Ascension by Gorillaz (Ft. Vince Staples)
# Andromeda by Gorillaz (Ft. Shelley FKA DRAM)
# Rhinestone Eyes by Gorillaz
# DARE by Gorillaz (Ft. Shaun Ryder)
# November Has Come by Gorillaz (Ft. MF DOOM)
# She’s My Collar by Gorillaz (Ft. Kali Uchis)
# _________________________
# {'highlights': [], 'index': 'song', 'type': 'song', 'result': {'annotation_count': 24, 'api_path': '/songs/21569', 'artist_names': 'Gorillaz (Ft. De La Soul)', 'full_title': 'Feel Good Inc. by\xa0Gorillaz (Ft.\xa0De\xa0La Soul)', 'header_image_thumbnail_url': 'https://images.genius.com/9e397a72939e26c604ef888be418e2ee.300x300x1.png', 'header_image_url': 'https://images.genius.com/9e397a72939e26c604ef888be418e2ee.1000x1000x1.png', 'id': 21569, 'lyrics_owner_id': 50, 'lyrics_state': 'complete', 'path': '/Gorillaz-feel-good-inc-lyrics', 'pyongs_count': 295, 'release_date_for_display': 'May 13, 2005', 'song_art_image_thumbnail_url': 'https://images.genius.com/1c1be607b75eb6b3f88686b16b073cad.300x300x1.jpg', 'song_art_image_url': 'https://images.genius.com/1c1be607b75eb6b3f88686b16b073cad.1000x1000x1.jpg', 'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 2045470}, 'title': 'Feel Good Inc.', 'title_with_featured': 'Feel Good Inc. (Ft.\xa0De\xa0La Soul)', 'url': 'https://genius.com/Gorillaz-feel-good-inc-lyrics', 'featured_artists': [{'api_path': '/artists/225', 'header_image_url': 'https://images.genius.com/54015a0b5441c3e94ff76a375494b4a6.996x608x1.jpg', 'id': 225, 'image_url': 'https://images.genius.com/74eced2a1a6baae90f5d2e678b1d494a.600x600x1.jpg', 'is_meme_verified': True, 'is_verified': True, 'name': 'De La Soul', 'url': 'https://genius.com/artists/De-la-soul', 'iq': 100}], 'primary_artist': {'api_path': '/artists/860', 'header_image_url': 'https://images.genius.com/4a68747ab7e13ac1e30f553fc04757dd.1000x333x1.jpg', 'id': 860, 'image_url': 'https://images.genius.com/c9182b5ecce1ab6d22ba0eaddb635424.400x400x1.jpg', 'is_meme_verified': False, 'is_verified': False, 'name': 'Gorillaz', 'url': 'https://genius.com/artists/Gorillaz'}}}
# Feel Good Inc. by Gorillaz (Ft. De La Soul) 2045470
# Clint Eastwood by Gorillaz (Ft. Del The Funky Homosapien) 1336075
# Saturnz Barz by Gorillaz (Ft. Popcaan) 792595
# On Melancholy Hill by Gorillaz 482736
# Ascension by Gorillaz (Ft. Vince Staples) 411580
# Andromeda by Gorillaz (Ft. Shelley FKA DRAM) 367271
# Rhinestone Eyes by Gorillaz 375297
# DARE by Gorillaz (Ft. Shaun Ryder) 346922
# November Has Come by Gorillaz (Ft. MF DOOM) 298200
# She’s My Collar by Gorillaz (Ft. Kali Uchis) 275653

# %%
missy_songs = []
for song in json_data['response']['hits']:
    missy_songs.append([song['result']['full_title'], song['result']['stats']
    ['pageviews']])
#Make a Pandas dataframe from a list
missy_df = pd.DataFrame(missy_songs)
missy_df.columns = ['song_title', 'page_views']
print(missy_df)
print("_____________________________")

def get_image_html(link):
    image_html = f"<img src='{link}' width='500px'>"
    return image_html
missy_songs = []
for song in json_data['response']['hits']:
    missy_songs.append([song['result']['full_title'], song['result']['stats']
    ['pageviews'], song['result']['song_art_image_url']])
missy_df = pd.DataFrame(missy_songs)
missy_df.columns = ['song_title', 'page_views','album_cover_url']
#Use the function get_image_html()
missy_df['album_cover'] = missy_df['album_cover_url'].apply(get_image_html)
print(missy_df)
HTML(missy_df[['album_cover', 'page_views', 'song_title']].to_html(escape=False))
# Out:
#                                           song_title  page_views
# 0        Feel Good Inc. by Gorillaz (Ft. De La Soul)     2045470
# 1  Clint Eastwood by Gorillaz (Ft. Del The Funky ...     1336075
# 2             Saturnz Barz by Gorillaz (Ft. Popcaan)      792595
# 3                     On Melancholy Hill by Gorillaz      482736
# 4          Ascension by Gorillaz (Ft. Vince Staples)      411580
# 5       Andromeda by Gorillaz (Ft. Shelley FKA DRAM)      367271
# 6                        Rhinestone Eyes by Gorillaz      375297
# 7                 DARE by Gorillaz (Ft. Shaun Ryder)      346922
# 8        November Has Come by Gorillaz (Ft. MF DOOM)      298200
# 9       She’s My Collar by Gorillaz (Ft. Kali Uchis)      275653
# _____________________________
#                                           song_title  page_views  \
# 0        Feel Good Inc. by Gorillaz (Ft. De La Soul)     2045470
# 1  Clint Eastwood by Gorillaz (Ft. Del The Funky ...     1336075
# 2             Saturnz Barz by Gorillaz (Ft. Popcaan)      792595
# 3                     On Melancholy Hill by Gorillaz      482736
# 4          Ascension by Gorillaz (Ft. Vince Staples)      411580
# 5       Andromeda by Gorillaz (Ft. Shelley FKA DRAM)      367271
# 6                        Rhinestone Eyes by Gorillaz      375297
# 7                 DARE by Gorillaz (Ft. Shaun Ryder)      346922
# 8        November Has Come by Gorillaz (Ft. MF DOOM)      298200
# 9       She’s My Collar by Gorillaz (Ft. Kali Uchis)      275653
#
#                                      album_cover_url  \
# 0  https://images.genius.com/1c1be607b75eb6b3f886...
# 1  https://images.genius.com/b9851dd5fb5d6f5948b3...
# 2  https://images.genius.com/23be9ca1a4f9093bc555...
# 3  https://images.genius.com/b4a931463c776935974c...
# 4  https://images.genius.com/796554d6df23ceeac5bb...
# 5  https://images.genius.com/39a660eba632a4a86901...
# 6  https://images.genius.com/effcde4cb8ec904dbe85...
# 7  https://images.genius.com/690f9bd5263245b796d5...
# 8  https://images.genius.com/5a07a907214435b0a99b...
# 9  https://images.genius.com/0d674b936604ee0c47fc...
#
#                                          album_cover
# 0  <img src='https://images.genius.com/1c1be607b7...
# 1  <img src='https://images.genius.com/b9851dd5fb...
# 2  <img src='https://images.genius.com/23be9ca1a4...
# 3  <img src='https://images.genius.com/b4a931463c...
# 4  <img src='https://images.genius.com/796554d6df...
# 5  <img src='https://images.genius.com/39a660eba6...
# 6  <img src='https://images.genius.com/effcde4cb8...
# 7  <img src='https://images.genius.com/690f9bd526...
# 8  <img src='https://images.genius.com/5a07a90721...
# 9  <img src='https://images.genius.com/0d674b9366...
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>album_cover</th>
#       <th>page_views</th>
#       <th>song_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src='https://images.genius.com/1c1be607b75eb6b3f88686b16b073cad.1000x1000x1.jpg' width='500px'></td>
#       <td>2045470</td>
#       <td>Feel Good Inc. by Gorillaz (Ft. De La Soul)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src='https://images.genius.com/b9851dd5fb5d6f5948b3fa1eb0d83992.1000x1000x1.jpg' width='500px'></td>
#       <td>1336075</td>
#       <td>Clint Eastwood by Gorillaz (Ft. Del The Funky Homosapien)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src='https://images.genius.com/23be9ca1a4f9093bc5556aa5e756c2c3.1000x1000x1.jpg' width='500px'></td>
#       <td>792595</td>
#       <td>Saturnz Barz by Gorillaz (Ft. Popcaan)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src='https://images.genius.com/b4a931463c776935974c43dbe57522e1.1000x1000x1.jpg' width='500px'></td>
#       <td>482736</td>
#       <td>On Melancholy Hill by Gorillaz</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src='https://images.genius.com/796554d6df23ceeac5bb14b12bd57ac8.1000x1000x1.jpg' width='500px'></td>
#       <td>411580</td>
#       <td>Ascension by Gorillaz (Ft. Vince Staples)</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src='https://images.genius.com/39a660eba632a4a8690157bd5dce10ea.1000x1000x1.png' width='500px'></td>
#       <td>367271</td>
#       <td>Andromeda by Gorillaz (Ft. Shelley FKA DRAM)</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src='https://images.genius.com/effcde4cb8ec904dbe85ff65dd7148f0.500x500x1.png' width='500px'></td>
#       <td>375297</td>
#       <td>Rhinestone Eyes by Gorillaz</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src='https://images.genius.com/690f9bd5263245b796d52990b2ee02e2.1000x1000x1.jpg' width='500px'></td>
#       <td>346922</td>
#       <td>DARE by Gorillaz (Ft. Shaun Ryder)</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src='https://images.genius.com/5a07a907214435b0a99b7206a6143a51.574x565x1.png' width='500px'></td>
#       <td>298200</td>
#       <td>November Has Come by Gorillaz (Ft. MF DOOM)</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src='https://images.genius.com/0d674b936604ee0c47fcff2de0577d2d.1000x1000x1.png' width='500px'></td>
#       <td>275653</td>
#       <td>She’s My Collar by Gorillaz (Ft. Kali Uchis)</td>
#     </tr>
#   </tbody>
# </table>
